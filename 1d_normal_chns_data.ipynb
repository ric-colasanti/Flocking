# %%
import math
import matplotlib.pyplot as plt
import random as rnd
import numpy as np
import networkx as nx
import seaborn as sns

from scipy.optimize import curve_fit
import warnings
warnings.filterwarnings('ignore')

# %%
bins=[i for i in range(0,121)]

# %%
chns = np.genfromtxt("Data/BW.csv", delimiter=",").tolist()
d_chns = np.genfromtxt("Data/D_BW.csv", delimiter=",").tolist()
pop = np.genfromtxt("Data/BW.csv", delimiter=",").tolist()
plt.hist(pop,alpha=0.3,edgecolor="black",bins=bins)
plt.show()
std = np.std(pop)
print(std)
population = len(pop)
for t in range(660):
    for i in range(population):
        pop[i]+=rnd.random()*0.02-0.008

plt.hist(pop,alpha=0.3,edgecolor="black",bins=bins)
plt.show()
std = np.std(pop)
print(std)
# Out:
# 11.257643960834283
# 11.257844918264492

# %%
#sns.distplot(chns,hist=False)
sns.distplot(d_chns,hist=False)
sns.distplot(pop,hist=False)
plt.show()
